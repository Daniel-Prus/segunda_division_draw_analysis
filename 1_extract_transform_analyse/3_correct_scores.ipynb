# %%
import numpy as np
import pandas as pd
from draw_analysis.draw_analysis import DrawAnalysis

# %%
fixtures = pd.read_csv('backup/segunda_division_fixtures_2018_2019_2020_2021_07_13.csv')

# %%
segunda_division = DrawAnalysis(fixtures)
# Out:
#  Data description:
# ...
# 	Country: Spain
#  	League name: Segunda Division
#  	League id: 141
#  	Seasons: 2018, 2019, 2020
# ...

# %%
segunda_division.fixtures_data.head()
# Out:
#    fixture_id              fixture_date  fixture_timestamp  league_id  \
# 0       27521 2018-08-17 18:00:00+00:00         1534528800        141
# 1       27519 2018-08-17 20:00:00+00:00         1534536000        141
# 2       27523 2018-08-18 17:00:00+00:00         1534611600        141
# 3       27526 2018-08-18 17:30:00+00:00         1534613400        141
# 4       27520 2018-08-18 18:30:00+00:00         1534617000        141
#
#         league_name league_country  league_season        league_round  \
# 0  Segunda Division          Spain           2018  Regular Season - 1
# 1  Segunda Division          Spain           2018  Regular Season - 1
# 2  Segunda Division          Spain           2018  Regular Season - 1
# 3  Segunda Division          Spain           2018  Regular Season - 1
# 4  Segunda Division          Spain           2018  Regular Season - 1
#
#    teams_home_id teams_home_name  ... teams_away_winner  goals_home  \
# ...

# %%
segunda_division.fixtures_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386 entries, 0 to 1385
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fixture_id             1386 non-null   int64
#  1   fixture_date           1386 non-null   datetime64[ns, UTC]
#  2   fixture_timestamp      1386 non-null   int64
#  3   league_id              1386 non-null   int64
#  4   league_name            1386 non-null   category
#  5   league_country         1386 non-null   category
#  6   league_season          1386 non-null   int64
#  7   league_round           1386 non-null   category
#  8   teams_home_id          1386 non-null   int64
#  9   teams_home_name        1386 non-null   category
#  10  teams_home_winner      953 non-null    category
#  11  teams_away_id          1386 non-null   int64
#  12  teams_away_name        1386 non-null   category
#  13  teams_away_winner      953 non-null    category
# ...

# %% [markdown]
# ### 1. Correct scores analysis - seasons 2018, 2019, 2020

# %%
# correct scores summary (total)
segunda_division.correct_scores(scores_type='fulltime')
# Out:
#                                      count  pcts(%)
# league_season fulltime_match_result
# 2018          1:0                       80    17.32
#               1:1                       73    15.80
#               0:0                       48    10.39
#               0:1                       40     8.66
#               2:0                       40     8.66
# ...                                    ...      ...
# 2020          3:3                        2     0.43
#               0:4                        1     0.22
#               0:5                        1     0.22
#               4:2                        1     0.22
#               6:1                        1     0.22
#
# [72 rows x 2 columns]

# %%
segunda_division.correct_scores_fulltime_plot()

# %%
segunda_division.correct_scores_fulltime_plot(plot_type='pcts')

# %%
segunda_division.correct_scores_halftime_plot()

# %%
segunda_division.correct_scores_halftime_plot(plot_type='pcts')

# %% [markdown]
# ### 2. Correct scores of draw results

# %%
segunda_division.correct_scores_draw_plot()

# %%
segunda_division.correct_scores_draw_plot(plot_type='pcts')
